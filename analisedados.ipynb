# %%
import pandas as pd #IMPORTA A BIBLIOTECA PANDAS
urlDados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true' #LINK DO ARQUIVO
dados = pd.read_csv(urlDados, compression = 'zip') #CRIA A VARIÁVEL PARA RETORNAR A TABELA

dados #CHAMA A VARIÁVEL
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head() #5 PRIMEIRAS LINHAS
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.tail() #APRESENTA AS 5 ÚLTIMAS LINHAS
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados.shape #(LINHAS, COLUNAS)
# Out:
# (23814, 877)

# %%
dados['id'] #SEPARA OS DADOS DE UMA COLUNA
# Out:
# 0        id_000644bb2
# 1        id_000779bfc
# 2        id_000a6266a
# 3        id_0015fd391
# 4        id_001626bd3
#              ...
# 23809    id_fffb1ceed
# 23810    id_fffb70c0c
# 23811    id_fffc1c3f4
# 23812    id_fffcb9e7c
# 23813    id_ffffdd77b
# Name: id, Length: 23814, dtype: object

# %%
dados['tratamento'] #SEPARANDO NOVAMENTE OUTRA COLUNA
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() #UNIQUE() É UTILIZADO PARA SEPARAR OS VALORES ÚNICOS DE UMA CERTA COLUNA
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique() #UTILIZANDO NOVAMENTE O MÉTODO
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique() #UTILIZANDO NOVAMENTE O MÉTODO
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique() #NESTE MOMENTO VERIFICAMOS QUE OS DADOS ESTÃO ANONIMIZADOS. PERCEBE-SE QUE ISSO FOI FEITO PARA NÃO DIRECIONAR O PESQUISADOR A UM PENSAMENTO ENVIESADO.
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique() #RECEBENDO OS VALORES DE g-0
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts() #NÚMERO DE EXPERIMENTOS FEITOS COM DROGAS E COM CONTROLE
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
print('Neste experimento foram utilizados', dados['droga'].nunique(), 'tipos de drogas') #CONTA OS ITENS SEM REPETI-LOS, OU SEJA, NESSE CASO FORAM UTILIZADOS 3289 TIPOS DE DROGAS
# Out:
# Neste experimento foram utilizados 3289 tipos de drogas

# %%
dados['tratamento'].value_counts(normalize = True) #COM O NORMALIZE VERDADEIRO, É MOSTRADA A PROPORÇÃO ENTRE OS VALORES
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# A grande variação entre esses dois tipos de experimento se dá por conta de não precisarmos de muitos controles. São feitos diversos experimentos e esses são comparados a seu respectivo grupo controle.

# %%
dados['tratamento'].value_counts().plot.pie(title='Proporção (TRATAMENTO) - Experimentos') #GRÁFICO DE PIZZA PARA REPRESENTAR A PROPORÇÃO DOS TRATAMENTOS

# %%
dados['tempo'].value_counts().plot.pie(title='Proporção (TEMPO) - Experimentos') #GRÁFICO DE PIZZA PARA REPRESENTAR A PROPORÇÃO DO TEMPO

# %%
dados['tempo'].value_counts().plot.bar(title='Proporção (TEMPO) - Experimentos') #GRÁFICO DE BARRAS PARA REPRESENTAR A PROPORÇÃO DO TEMPO

# %%
dados['g-0'] > 0 #VERIFICANDO QUAIS LINHAS POSSUEM O g-0 MAIOR QUE 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dadosFiltrados = dados[dados['g-0'] > 0] #OS DADOS FILTRADOS SERÃO OS QUE g-0 É MAIOR QUE 0
dadosFiltrados.head() #NESTA PARTE, FORAM SELECIONADOS AS 5 PRIMEIRAS LINHAS DOS DADOS FILTRADOS
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Falta a parte de matplotlib e tentar renomear o g-0 para g0

# %%
dados.rename(columns = {"g-0": "g0"}, inplace=True) #RENOMEIA A COLUNA DESEJADA

# %%
dados.head() #TESTE PARA VERIFICAR A ALTERAÇÃO
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.rename(columns={dados.columns[6]: 'g1'}) #RENOMEIA DE ACORDO COM O INDEX DA COLUNA
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.columns = [x.replace('-','') for x in dados.columns] #TIRA OS HÍFENS DOS TERMOS, PARA EVITAR ERROS
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
import matplotlib.pyplot as plt #CRIANDO GRÁFICO VISUALMENTE BONITO

plt.grid(color='gray', linestyle=(0, (5, 10)), linewidth=1, axis='y', alpha=0.3)
plt.bar(x_label,dados['tempo'].value_counts(sort=True).sort_index(), color='lightblue', zorder=3)
plt.title('Proporção (TEMPO) - Experimentos')
plt.xlabel('Tempo do Experimento')
plt.ylabel('Quantidade')
plt.show()
